# %%
print("Hello, students! Welcome to our course! ")
# single comment
# Out:
# Hello, students! Welcome to our course!

# %%
'''
Multi-line comments example
'''
# Out:
# '\nMulti-line comments example\n'

# %%
a = int(input())
print(a)
print(type(a))
print(id(a)) # id of the object
# Out:
#  2
# 2
# <class 'int'>
# 140725219224024

# %%
# неизменяемые типы: числа, строки, кортежи, булевые значения
# изменяемые: списки, словари

# %% [markdown]
# ![image.png](attachment:84683456-be0a-483c-b4a3-158589dd6c4e.png)

# %%
a = 123
b = a
a = 10
print(a,b)
# Out:
# 10 123

# %%
x,y = 'car', 2

print(x,y)
print(type(x))
print(type(y))
# Out:
# car 2
# <class 'str'>
# <class 'int'>

# %%
# Formatting output
a,b,=10,1000
print('The value of a is {} and b is {}'.format(a,b))
print(a, b)
print(a,b, sep='*')
# Out:
# The value of a is 10 and b is 1000
# 10 1000
# 10*1000

# %%
#a = complex(input())
a = complex(0,1)
print(a)
# Out:
# 1j

# %%
#dec
a = 10
print(a)
# Out:
# 10

# %%
#bin
a = 0b10
print(a)
# Out:
# 2

# %%
#oct
a = 0O123
print(a)
# Out:
# 83

# %%
#hex
a = 0X12A
print(a)
# Out:
# 298

# %%
f = .3
print(f)
print(0.3)
f = .04e3
print(f)
# Out:
# 0.3
# 0.3
# 40.0

# %%
flag = True
print(flag)
print(type(flag))
# Out:
# True
# <class 'bool'>

# %%
t = {}
print(bool(t))
# Out:
# False

# %%
s = 3 < 4
print(s)
# Out:
# True

# %%
s = set((1,2,3,))
print(s)
print(type(s))
# Out:
# {1, 2, 3}
# <class 'set'>

# %%
my_list1 = list((1, 2, 3))
print(my_list1)
# Out:
# [1, 2, 3]

# %%
# Using square brackets[]
my_list2 = [1, 2, 3]
print(my_list2)
# Out:
# [1, 2, 3]

# %%
my_list3 = [1.0, 'Jessa', 3]
print(my_list3)
# Out:
# [1.0, 'Jessa', 3]

# %%
# empty list using list()
my_list4 = list()
print(my_list4)
# Out:
# []

# %%
# empty list using []
my_list5 = []
print(my_list4)
# Out:
# []

# %%
a = [1,2,3,4]
print(a[0])
print(a[3])
print(a[-1])
print(a[-2])

print(a)
print(a[:2])
print(a[1:])
# Out:
# 1
# 4
# 4
# 3
# [1, 2, 3, 4]
# [1, 2]
# [2, 3, 4]

# %%
print(a[1:3])
# Out:
# [2, 3]

# %%
a[2] = 10
a[1] = a[3]**3
a.append(67)

# %%
print(a)
# Out:
# [1, 64, 10, 4, 67]

# %%
print(sum(a))
# Out:
# 146

# %%
a.append(1)
print(a)
# Out:
# [1, 64, 10, 4, 67, 1]

# %%
s_a = set(a)
print(s_a)
# Out:
# {64, 1, 67, 4, 10}

# %%
print(len(a))
print(len(s_a))
# Out:
# 6
# 5

# %%
'''

######################### DICTIONARY ##########################

'''
d = {'a': 1, 'b':2 }
print(d)
print(d['a'])
d['d'] = 10
print(d)
# Out:
# {'a': 1, 'b': 2}
# 1
# {'a': 1, 'b': 2, 'd': 10}

# %%
'''
####################### TUPLE ######################

'''
t = 12345, 54321, 'hello!'
print(t)
print(type(t))
print(t[0])
# Out:
# (12345, 54321, 'hello!')
# <class 'tuple'>
# 12345
